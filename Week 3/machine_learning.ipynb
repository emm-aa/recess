# %%
import sys
print(sys.executable)
# Out:
# /home/emmaa/projects/.venv/bin/python

# %%
# Import Libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = {
    'Size': [650, 800, 1000, 1200, 1500, 1800, 2000, 2200, 2500, 2800], 'Bedrooms': [2, 2, 3, 3, 3, 4, 4, 4, 5, 5], 'Age': [20, 15, 10, 12, 8, 5, 3, 1, 2, 0], 'Price': [150000, 180000, 220000, 250000, 300000, 350000, 400000, 450000, 500000, 550000]
}

df = pd.DataFrame(data)

# %%
# Prepare data
x = df[['Size', 'Bedrooms', 'Age']] # Independent variables
y = df['Price'] # Dependant variable

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Regression Results')
print(f'Prediction: {y_pred}')
print(f'Actual: {y_test.values}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Regression Results
# Prediction: [488118.75677417 180084.95181182]
# Actual: [500000 180000]
# Mean Squared Error: 70585578.70077471
# R-squared: 0.997242750832001

# %%
'''
Classification - Predicting Customer Churn (Will the customer leave?)

Goal: Predict whether a customer will churn (Yes=1) or not (No=0).

Model: Logistic Regression (Predicts the probability of a binary outcome).

create sample data

data = {

 'MonthlyCharge': [50, 80, 70, 40, 90, 60, 100, 85, 45, 75],

 'ContractLength': [12, 6, 24, 12, 3, 18, 24, 6, 12, 18],

 'Age': [30, 25, 40, 35, 28, 50, 45, 32, 29, 55],

 'Churn': [0, 1, 0, 0, 1, 0, 0, 1, 0, 0] # 0 = No Churn, 1 = Churn

}

'''
# Accuracy score, confuion matrix, classification_ report
